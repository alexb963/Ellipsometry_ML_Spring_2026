# %%
# %run Functions_NCS-2-9-26.ipynb

# %%
import random

# %%
# First load in optical properties

os.chdir(r'C:\Users\bordo\Desktop\Python_Programs\Project4\Exercise1\wvw')

file = 'Junda_SLG.csv'
Glass = pd.read_csv(file)
Glass.name = 'Glass'
wv = Glass['Wavelength (nm)'].to_numpy()


### CdSe ###########
file = 'CdSe-wvw.csv'
CdSe = pd.read_csv(file)
CdSe.name = 'CdSe'
CdSe['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdSe['e1']
e2 = CdSe['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdSe['N'] = N


###### CdTe_15_Se_85 ###########
file = 'CdTe_15_Se_85-wvw.csv'
CdTe_15_Se_85 = pd.read_csv(file)
CdTe_15_Se_85.name = 'CdTe_15_Se_85'
CdTe_15_Se_85['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_15_Se_85['e1']
e2 = CdTe_15_Se_85['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_15_Se_85['N'] = N


###### CdTe_25_Se_75 ###########

file = 'CdTe_25_Se_75-wvw.csv'
CdTe_25_Se_75 = pd.read_csv(file)
CdTe_25_Se_75.name = 'CdTe_25_Se_75'
CdTe_25_Se_75['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_25_Se_75['e1']
e2 = CdTe_25_Se_75['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_25_Se_75['N'] = N


#### CdTe_38_Se_62 ##### 

file = 'CdTe_38_Se_62-wvw.csv'
CdTe_38_Se_62 = pd.read_csv(file)
CdTe_38_Se_62.name = 'CdTe_38_Se_62'
CdTe_38_Se_62['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_38_Se_62['e1']
e2 = CdTe_38_Se_62['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_38_Se_62['N'] = N


#### CdTe_54_Se_46 ##### 

file = 'CdTe_54_Se_46-wvw.csv'
CdTe_54_Se_46 = pd.read_csv(file)
CdTe_54_Se_46.name = 'CdTe_54_Se_46'
CdTe_54_Se_46['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_54_Se_46['e1']
e2 = CdTe_54_Se_46['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_54_Se_46['N'] = N



#### CdTe_64_Se_36 ##### 
file = 'CdTe_64_Se_36-wvw.csv'
CdTe_64_Se_36 = pd.read_csv(file)
CdTe_64_Se_36.name = 'CdTe_64_Se_36'
CdTe_64_Se_36['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_64_Se_36['e1']
e2 = CdTe_64_Se_36['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_64_Se_36['N'] = N



#### CdTe_69_Se_31 ##### 

file = 'CdTe_69_Se_31-wvw.csv'
CdTe_69_Se_31 = pd.read_csv(file)
CdTe_69_Se_31.name = 'CdTe_69_Se_31'
CdTe_69_Se_31['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_69_Se_31['e1']
e2 = CdTe_69_Se_31['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_69_Se_31['N'] = N


#### CdTe_75_Se_25 #####  

file = 'CdTe_75_Se_25-wvw.csv'
CdTe_75_Se_25 = pd.read_csv(file)
CdTe_75_Se_25.name = 'CdTe_75_Se_25'
CdTe_75_Se_25['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_75_Se_25['e1']
e2 = CdTe_75_Se_25['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_75_Se_25['N'] = N


#### CdTe_86_Se_14 #####  

file = 'CdTe_86_Se_14-wvw.csv'
CdTe_86_Se_14 = pd.read_csv(file)
CdTe_86_Se_14.name = 'CdTe_86_Se_14'
CdTe_86_Se_14['Wavelength (nm)'] = wv

# Calculate and add N
e1 = CdTe_86_Se_14['e1']
e2 = CdTe_86_Se_14['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe_86_Se_14['N'] = N


#### CdTe #####  

file = 'CdTe-wvw.csv'
CdTe = pd.read_csv(file)
CdTe.name = 'CdTe'
CdTe['Wavelength (nm)'] = wv
# Calculate and add N
e1 = CdTe['e1']
e2 = CdTe['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
CdTe['N'] = N



file = 'Junda_SLG.csv'
Glass = pd.read_csv(file)
Glass.name = 'Glass'

e1 = Glass['e1']
e2 = Glass['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
Glass['N'] = N


file ='Void.csv'
Void = pd.read_csv(file)
Void.name = 'Void'

e1 = Void['e1']
e2 = Void['e2']
n, k = calculate_n_k(e1, e2)
N = n + k*1j
Void['N'] = N

# %%
Glass
# Out:
#      Energy (eV)  Wavelength (nm)        e1        e2         n         k  \
# 0       5.867289       211.341217  2.524677  0.001758  1.588923  0.000553
# 1       5.823440       212.932571  2.518626  0.001682  1.587018  0.000530
# 2       5.780241       214.523956  2.512788  0.001610  1.585178  0.000508
# 3       5.737676       216.115387  2.507151  0.001541  1.583399  0.000487
# 4       5.695733       217.706833  2.501708  0.001476  1.581679  0.000467
# ..           ...              ...       ...       ...       ...       ...
# 692     0.740752      1673.974976  2.225308  0.000008  1.491747  0.000003
# 693     0.739240      1677.398071  2.225205  0.000008  1.491712  0.000003
# 694     0.737735      1680.820557  2.225101  0.000008  1.491677  0.000003
# 695     0.736236      1684.242432  2.224998  0.000008  1.491643  0.000003
# 696     0.734744      1687.663696  2.224894  0.000008  1.491608  0.000003
#
#                       N
# 0    1.588923+0.000553j
# 1    1.587018+0.000530j
# 2    1.585178+0.000508j
# 3    1.583399+0.000487j
# 4    1.581679+0.000467j
# ..                  ...
# 692  1.491747+0.000003j
# 693  1.491712+0.000003j
# 694  1.491677+0.000003j
# 695  1.491643+0.000003j
# 696  1.491608+0.000003j
#
# [697 rows x 7 columns]

# %% [markdown]
# In this exercise, we will make simulated ellipsometric spectra with the structure Void, CST, CdTe, Glass. The CST layer will have a varying composition and the thickness of the CST and CdTe layers will be variable.

# %%
CST_List = [
    CdTe_86_Se_14, 
    CdTe_75_Se_25,
    CdTe_69_Se_31,
    CdTe_64_Se_36,
    CdTe_54_Se_46,
    CdTe_38_Se_62,
    CdTe_25_Se_75,
    CdTe_15_Se_85,
    CdSe,
]


num_file = 1 
    
for i in range(len( CST_List )):

    print(Void.name)
    print(CST_List[i].name)
    print(CdTe.name)
    print(Glass.name)
    print("***********")

    for j in range(num_file):

        # Generate ellipsometric spectra

        # Step 1: Define Structure
    
        Structure = [
            Void, # always void
            CST_List[i], # varying CST layer
            CdTe, # Always CdTe 
            Glass # Always glass
        ]

        # Step 2: Define thicknesses 

        CST_Thickness = random.randrange(50, 500) # thickness in nm
        CdTe_Thickness = random.randrange(500, 1500) # thickness in nm

        print('CST_Thickness', CST_Thickness)
        print('CdTe_Thickness', CdTe_Thickness)
        print("***********")

        # Step 3: Take Thickness and Structure to make Ellipsometric spectra

        Thickness = [
            CST_Thickness,
            CdTe_Thickness
        ]

        AOI = 60

        df = SE_Sim(Structure, AOI, Thickness)
# Out:
# Void
# CdTe_86_Se_14
# CdTe
# Glass
# ***********
# CST_Thickness 87
# CdTe_Thickness 686
# ***********
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'N'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 55
#      48 Thickness = [
#      49     CST_Thickness,
#      50     CdTe_Thickness
#      51 ]
#      53 AOI = 60
# ---> 55 df = SE_Sim(Structure, AOI, Thickness)
#
# File ~\AppData\Local\Temp\ipykernel_14112\1951326360.py:41, in SE_Sim(Structure, AOI, d, write_data, NCS)
#      39 def SE_Sim(Structure, AOI, d, write_data=False, NCS=True):
#      40     wv = Structure[0]['Wavelength (nm)'].to_numpy()
# ---> 41     Nmat = np.stack([df["N"].to_numpy() for df in Structure])
#      42     angles = Snells_Law(Structure, AOI)
#      43     rs, rp, ts, tp = fresnel_coefficients(Nmat, angles)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'N'

# %%
CdTe_75_Se_25
# Out:
#      Energy (eV)        e1        e2
# 0       5.867289 -1.421814  5.901753
# 1       5.823440 -1.451528  6.122399
# 2       5.780241 -1.428915  6.367458
# 3       5.737676 -1.411785  6.596401
# 4       5.695733 -1.344172  6.819193
# ..           ...       ...       ...
# 692     0.740752  6.859385  0.012584
# 693     0.739240  6.857032  0.014851
# 694     0.737735  6.857789  0.016742
# 695     0.736236  6.856582  0.020953
# 696     0.734744  6.857101  0.024724
#
# [697 rows x 3 columns]
